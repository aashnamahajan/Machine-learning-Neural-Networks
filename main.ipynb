# %%
import proj2_part1
import proj2_part2
import proj2_part3

if __name__ == "__main__":
    proj2_part1.function_part_1()
    proj2_part2.function_part2()
    proj2_part3.function_part3()
# Out:
# C:\Users\Aashna Mahajan\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# Epoch 0 cost:  7.943808419749444
# Epoch 100 cost:  0.8301153829954303
# Epoch 200 cost:  0.7058359954033546
# Epoch 300 cost:  0.6455328293446279
# Epoch 400 cost:  0.6057978968369973
# Epoch 500 cost:  0.5770156186242881
# Epoch 600 cost:  0.5544823921879093
# Epoch 700 cost:  0.5359808237231136
# Epoch 800 cost:  0.5206918215865346
# Epoch 900 cost:  0.5081365666979931
# Epoch 1000 cost:  0.4980865340771888
# Epoch 1100 cost:  0.48968450176602907
# Epoch 1200 cost:  0.48218058496190075
# Epoch 1300 cost:  0.47540181518483066
# Epoch 1400 cost:  0.4692242544619556
# Final cost: 0.4635988265690342
# ...
